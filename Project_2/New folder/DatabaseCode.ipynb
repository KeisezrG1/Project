# %%
import pymongo
import random
from datetime import datetime, timedelta

# Replace with your MongoDB Atlas connection string
mongo_uri = "mongodb+srv://KeisezrG:Shro0odRowdy@cluster0.a1fqnoh.mongodb.net/?retryWrites=true&w=majority";

# Connect to the MongoDB Atlas cluster
client = pymongo.MongoClient(mongo_uri)

# Access the library management database
db = client["library_management"]

# Define user data
users_data = [
    {
        "username": "Shroud",
        "password": "Shrimpmeme",
        "full_name": "Micheal Grzesiek",
        "address": "",
        "phone_number": "+1 (407)408-3307",
        "email": "Micheal.Grzesiek@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "Wolverine",
        "password": "Loganisthebestmovie",
        "full_name": "Hugh Jackman",
        "address": "",
        "phone_number": "+1 (407)408-3308",
        "email": "Hugh.Jackman@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "Superman",
        "password": "Cavilisbestsuperman",
        "full_name": "Henry Cavill",
        "address": "",
        "phone_number": "+1 (407)408-3309",
        "email": "Henry.Cavill@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "Egzy",
        "password": "Kingsman",
        "full_name": "Taron Egerton",
        "address": "",
        "phone_number": "+1 (407)408-3310",
        "email": "Taron.Egerton@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "Batsy",
        "password": "IamBatman",
        "full_name": "Bruce Wayne",
        "address": "",
        "phone_number": "+1 (407)408-3311",
        "email": "Bruce.Wayne@batcave.com",
        "is_library_manager": False
    },
    {
        "username": "Versatile",
        "password": "bestactor",
        "full_name": "Pedro Pascal",
        "address": "",
        "phone_number": "+1 (407)408-3312",
        "email": "Pedro.Pascal@hotmail.com",
        "is_library_manager": False
    },
    {
        "username": "DeanWinchester",
        "password": "Sexyguy",
        "full_name": "Jensen Ackles",
        "address": "",
        "phone_number": "+1 (408)408-3313",
        "email": "Jensen.Ackles@hotmail.com",
        "is_library_manager": False
    },
    {
        "username": "Cowboy",
        "password": "Micahisarat",
        "full_name": "Authur Morgan",
        "address": "",
        "phone_number": "+1 (407)408-3314",
        "email": "Arthur.Morgan@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "Eminem",
        "password": "SlimShady",
        "full_name": "Bruce Mathers",
        "address": "",
        "phone_number": "+1 (407)408-3315",
        "email": "",
        "is_library_manager": False
    },
    {
        "username": "Nolan",
        "password": "THEDirector",
        "full_name": "Christopher Nolan",
        "address": "",
        "phone_number": "+1(407)408-3316",
        "email": "Christopher.Nolan@gmail.com",
        "is_library_manager": False
    },
    {
        "username": "KeisezrG",
        "password": "Shro0odRowdy&",
        "full_name": "KanvaKoushik Gopavarapu",
        "address": "",
        "phone_number": "+1(407)408-3306",
        "email": "KanvaKoushik.Gopavarapu@outlook.com",
        "is_library_manager": True
    },
    { 
        "username": "Violet",
        "password": "BTSarmy",
        "full_name": "Varshini Surapaneni",
        "address": "",
        "phone_number": "+1(806)451-6727",
        "email": "Varshini.Surapaneni@gmail.com",
        "is_library_manager": True
    },
    # Add more users here...
]

# Define book data
books_data = [
    {
        "title": "The Great Gatsby",
        "description": "A story of the fabulously wealthy Jay Gatsby and his love for the beautiful Daisy Buchanan.",
        "price": 12.99,
        "author": "F. Scott Fitzgerald",
        "publisher": "Scribner",
        "available_copies": 3
    },
    {
        "title": "To Kill a Mockingbird",
        "description": "A powerful story of racial injustice and the loss of innocence in the Deep South.",
        "price": 11.50,
        "author": "Harper Lee",
        "publisher": "J. B. Lippincott & Co.",
        "available_copies": 2
    },
    {
        "title": "1984",
        "description": "A dystopian novel set in a totalitarian society, where the government controls every aspect of life.",
        "price": 14.75,
        "author": "George Orwell",
        "publisher": "Secker & Warburg",
        "available_copies": 4
    },
    {
        "title": "Pride and Prejudice",
        "description": "The story of the independent and strong-minded Elizabeth Bennet and the proud Mr. Darcy.",
        "price": 10.99,
        "author": "Jane Austen",
        "publisher": "T. Egerton, Whitehall",
        "available_copies": 3
    },
    {
        "title": "The Hobbit",
        "description": "The tale of Bilbo Baggins and his unexpected journey to claim a treasure guarded by the dragon Smaug.",
        "price": 9.25,
        "author": "J.R.R. Tolkien",
        "publisher": "George Allen & Unwin",
        "available_copies": 5
    },
    {
        "title": "Harry Potter and the Sorcerer's Stone",
        "description": "The story of a young wizard, Harry Potter, as he discovers his magical heritage.",
        "price": 15.99,
        "author": "J.K. Rowling",
        "publisher": "Bloomsbury",
        "available_copies": 2
    },
    {
        "title": "Moby-Dick",
        "description": "The tale of Captain Ahab's obsessive quest for revenge on the elusive white whale Moby Dick.",
        "price": 13.45,
        "author": "Herman Melville",
        "publisher": "Richard Bentley",
        "available_copies": 3
    },
    {
        "title": "The Catcher in the Rye",
        "description": "The story of Holden Caulfield, a disaffected teenager struggling with the hypocrisy of society.",
        "price": 10.80,
        "author": "J.D. Salinger",
        "publisher": "Little, Brown and Company",
        "available_copies": 4
    },
    {
        "title": "The Lord of the Rings: The Fellowship of the Ring",
        "description": "The first part of the epic fantasy journey of the Fellowship to destroy the One Ring.",
        "price": 16.75,
        "author": "J.R.R. Tolkien",
        "publisher": "George Allen & Unwin",
        "available_copies": 5
    },
    {
        "title": "The Little Prince",
        "description": "A philosophical novella about a young prince who travels the universe and learns about life, love, and friendship.",
        "price": 8.95,
        "author": "Antoine de Saint-Exupéry",
        "publisher": "Reynal & Hitchcock",
        "available_copies": 3
    },
    {
        "title": "Fahrenheit 451",
        "description": "In a future society where books are banned, a fireman tasked with burning them begins to question his role.",
        "price": 12.30,
        "author": "Ray Bradbury",
        "publisher": "Ballantine Books",
        "available_copies": 2
    },
    {
        "title": "The Great Expectations",
        "description": "The coming-of-age story of a young orphan named Pip and his journey through life.",
        "price": 11.20,
        "author": "Charles Dickens",
        "publisher": "Chapman & Hall",
        "available_copies": 4
    },
    {
        "title": "One Hundred Years of Solitude",
        "description": "A multi-generational story of the Buendía family, set in the fictional town of Macondo.",
        "price": 14.99,
        "author": "Gabriel García Márquez",
        "publisher": "Harper & Row",
        "available_copies": 3
    },
    {
        "title": "Brave New World",
        "description": "A dystopian novel set in a society where genetic engineering and psychological conditioning maintain order.",
        "price": 13.25,
        "author": "Aldous Huxley",
        "publisher": "Chatto & Windus",
        "available_copies": 5
    },
    {
        "title": "The Odyssey",
        "description": "The epic poem recounting the journey of Odysseus after the fall of Troy.",
        "price": 9.90,
        "author": "Homer",
        "publisher": "William Heinemann",
        "available_copies": 3
    },
    {
        "title": "Jane Eyre",
        "description": "The story of a young orphan, Jane Eyre, and her journey to become an independent woman.",
        "price": 10.50,
        "author": "Charlotte Brontë",
        "publisher": "Smith, Elder & Co.",
        "available_copies": 4
    },
    {
        "title": "The Chronicles of Narnia: The Lion, the Witch and the Wardrobe",
        "description": "The story of four children who discover the magical land of Narnia through a wardrobe.",
        "price": 12.75,
        "author": "C.S. Lewis",
        "publisher": "Geoffrey Bles",
        "available_copies": 5
    },
    {
        "title": "Crime and Punishment",
        "description": "The psychological novel about a man who commits a crime and faces the consequences.",
        "price": 11.60,
        "author": "Fyodor Dostoevsky",
        "publisher": "The Russian Messenger",
        "available_copies": 3
    },
    {
        "title": "The Picture of Dorian Gray",
        "description": "A cautionary tale about vanity and the corruption of the soul.",
        "price": 10.25,
        "author": "Oscar Wilde",
        "publisher": "Ward, Lock and Co.",
        "available_copies": 4
    },
    {
        "title": "The Hitchhiker's Guide to the Galaxy",
        "description": "The humorous sci-fi adventure of Arthur Dent as he travels through space and time.",
        "price": 9.95,
        "author": "Douglas Adams",
        "publisher": "Pan Books",
        "available_copies": 2
    },
    {
        "title": "Anna Karenina",
        "description": "The tragic story of Anna Karenina, who falls in love with the dashing Count Vronsky.",
        "price": 12.90,
        "author": "Leo Tolstoy",
        "publisher": "The Russian Messenger",
        "available_copies": 5
    },
    {
        "title": "The Book Thief",
        "description": "Set in Nazi Germany, a young girl steals books to share them with others and find solace.",
        "price": 11.75,
        "author": "Markus Zusak",
        "publisher": "Picador",
        "available_copies": 3
    },
    {
        "title": "Wuthering Heights",
        "description": "A dark and passionate tale of love, revenge, and obsession on the moors.",
        "price": 10.50,
        "author": "Emily Brontë",
        "publisher": "Thomas Cautley Newby",
        "available_copies": 4
    },
    {
        "title": "The Divine Comedy",
        "description": "The epic poem by Dante Alighieri, describing the journey through Hell, Purgatory, and Heaven.",
        "price": 15.99,
        "author": "Dante Alighieri",
        "publisher": "Foligno",
        "available_copies": 5
    },
    {
        "title": "The Alchemist",
        "description": "The story of Santiago, an Andalusian shepherd boy, and his quest for a hidden treasure.",
        "price": 8.95,
        "author": "Paulo Coelho",
        "publisher": "HarperOne",
        "available_copies": 3
    },
    {
        "title": "The Count of Monte Cristo",
        "description": "The tale of Edmond Dantès and his quest for revenge after being wrongly imprisoned.",
        "price": 12.20,
        "author": "Alexandre Dumas",
        "publisher": "Revue des Deux Mondes",
        "available_copies": 2
    },
    {
        "title": "The Name of the Wind",
        "description": "The story of Kvothe, a magically gifted young man who grows to be the most notorious wizard.",
        "price": 14.50,
        "author": "Patrick Rothfuss",
        "publisher": "DAW Books",
        "available_copies": 4
    },
    {
        "title": "Dracula",
        "description": "The gothic horror novel about the vampire Count Dracula and his attempt to move from Transylvania to England.",
        "price": 10.75,
        "author": "Bram Stoker",
        "publisher": "Archibald Constable and Company",
        "available_copies": 3
    },
    {
        "title": "The Road",
        "description": "The post-apocalyptic tale of a father and son's journey across a desolate landscape.",
        "price": 11.99,
        "author": "Cormac McCarthy",
        "publisher": "Alfred A. Knopf",
        "available_copies": 2
    },
    {
        "title": "The Kite Runner",
        "description": "The story of Amir, a young boy from Kabul, and his journey to find redemption.",
        "price": 11.45,
        "author": "Khaled Hosseini",
        "publisher": "Riverhead Books",
        "available_copies": 4
    },
    {
        "title": "Frankenstein",
        "description": "The tale of Victor Frankenstein and his creation, the monster often referred to as Frankenstein.",
        "price": 9.80,
        "author": "Mary Shelley",
        "publisher": "Lackington, Hughes, Harding, Mavor, & Jones",
        "available_copies": 5
    },

    # Add more books here...
]

# Populate Users Collection
users_collection = db["users"]
users_collection.insert_many(users_data)

# Populate Books Collection
books_collection = db["books"]
books_collection.insert_many(books_data)

# Generate random loan records
loan_records_data = []
for _ in range(100):  # Generate 100 loan records
    user = random.choice(users_data)
    book = random.choice(books_data)

    borrow_date = datetime.utcnow()
    due_date = borrow_date + timedelta(days=random.randint(7, 21))
    return_date = borrow_date + timedelta(days=random.randint(1, 14))

    loan_record = {
        "user_id": user["_id"],
        "book_id": book["_id"],
        "borrow_date": borrow_date,
        "due_date": due_date,
        "return_date": return_date if return_date < due_date else None
    }

    loan_records_data.append(loan_record)

# Populate Loan Records Collection
loan_records_collection = db["loan_records"]
loan_records_collection.insert_many(loan_records_data)

print("Database population completed.")
# Out:
# Database population completed.
